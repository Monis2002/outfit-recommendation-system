# %%
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Functions

# %% [markdown]
# ### Random Time

# %%
import random
from datetime import datetime, timedelta

def generate_random_datetime():
    # Define the start and end dates
    start_date = datetime(2000, 1, 1)
    end_date = datetime(2020, 12, 31)

    # Generate a random number of days between start and end
    random_days = random.randint(0, (end_date - start_date).days)

    # Calculate the random date
    random_date = start_date + timedelta(days=random_days)

    # Generate random hours, minutes, and seconds
    random_hours = random.randint(0, 23)
    random_minutes = random.randint(0, 59)
    random_seconds = random.randint(0, 59)

    # Combine date and time components
    random_datetime = random_date.replace(
        hour=random_hours, minute=random_minutes, second=random_seconds
    )

    return random_datetime

# Example usage
random_datetime = generate_random_datetime()
print("Random Date and Time:", random_datetime)
# Out:
# Random Date and Time: 2018-09-01 13:05:59

# %% [markdown]
# ### DataFrame Forming

# %%
def form_df(dir_path):
    dic_list=[]
    path_list=os.listdir(dir_path)
    weather=input('Weather:  ')
    Type=input("Type:  ")
    gender=input("Gender:  ")

    for path in path_list:
        r=os.path.join(dir_path,path)
        d={'Date':generate_random_datetime(),'Type':Type,'Gender':gender,'weather':weather,'Path':r}
        dic_list.append(d)
    return pd.DataFrame(dic_list)

# %% [markdown]
# ### Varification

# %%
def verify(df):
    idx=np.random.randint(df.shape[0])
    img=df.loc[idx,'Path']
    img_array=cv2.imread(img)
    plt.axis('off')
    plt.imshow(img_array)
    return plt.show()

# %% [markdown]
# ## Formal-Men-Summer

# %%
formal_men_summer_df=form_df('dataset\\formal_men_summer')
# Out:
# Weather:  Summer
# Type:  Formal
# Gender:  Men

# %%
formal_men_summer_df.shape
# Out:
# (342, 5)

# %%
verify(formal_men_summer_df)

# %% [markdown]
# ## Formal-Men-Winter

# %%
formal_men_winter_df=form_df('dataset\\formal_men_winter')
# Out:
# Weather:  Winter
# Type:  Formal
# Gender:  Men

# %%
formal_men_winter_df.shape
# Out:
# (70, 5)

# %%
verify(formal_men_winter_df)

# %% [markdown]
# ## casual_men_winter

# %%
casual_men_winter_df=form_df('dataset\\casual_men_winter')
# Out:
# Weather:  Winter
# Type:  Casual
# Gender:  Men

# %%
casual_men_winter_df.shape
# Out:
# (55, 5)

# %%
verify(casual_men_winter_df)

# %% [markdown]
# ## casual_men_summer

# %%
casual_men_summer_df=form_df('dataset\\casual_men_summer')
# Out:
# Weather:  Summer
# Type:  Casual
# Gender:  Men

# %%
casual_men_summer_df.shape
# Out:
# (121, 5)

# %%
verify(casual_men_summer_df)

# %% [markdown]
# ## casual _women_winter

# %%
casual_women_winter_df=form_df('dataset\\casual_women_winter')
# Out:
# Weather:  Winter
# Type:  Casual
# Gender:  Women

# %%
casual_women_winter_df.shape
# Out:
# (37, 5)

# %%
verify(casual_women_winter_df)

# %% [markdown]
# ## casual _women_summer

# %%
casual_women_summer_df=form_df('dataset\\casual_women_summer')
# Out:
# Weather:  Summer
# Type:  Casual
# Gender:  Women

# %%
casual_women_summer_df.shape
# Out:
# (105, 5)

# %%
verify(casual_women_summer_df)

# %% [markdown]
# ## beach_men

# %%
dir_path='dataset\\beach_men'
dic_list=[]
path_list=os.listdir(dir_path)
weather=['Summer','Winter']
Type=input("Type:  ")
gender=input("Gender:  ")

for path in path_list:
    r=os.path.join(dir_path,path)
    d={'Date':generate_random_datetime(),'Type':Type,'Gender':gender,'weather':np.random.choice(weather),'Path':r}
    dic_list.append(d)

beach_df=pd.DataFrame(dic_list)
# Out:
# Type:  Beach
# Gender:  Men

# %% [markdown]
# # Final DataFrame

# %%
list_df=[casual_women_summer_df,casual_women_winter_df,casual_men_summer_df,casual_men_winter_df,formal_men_winter_df,formal_men_summer_df,beach_df]

# %%
final_df=pd.concat(list_df,axis=0,ignore_index=True)

# %%
final_df.shape
# Out:
# (819, 5)

# %%
final_df1=final_df.sample(frac=1,random_state=42,ignore_index=True)

# %%
final_df.head()
# Out:
#                  Date    Type Gender weather  \
# 0 2009-11-22 01:28:58  Casual  Women  Summer
# 1 2011-01-17 02:54:32  Casual  Women  Summer
# 2 2002-01-19 14:35:58  Casual  Women  Summer
# 3 2001-01-28 00:47:47  Casual  Women  Summer
# 4 2007-08-15 03:50:46  Casual  Women  Summer
#
#                                                 Path
# 0  dataset\casual_women_summer\Screenshot_2023123...
# 1  dataset\casual_women_summer\Screenshot_2023123...
# 2  dataset\casual_women_summer\Screenshot_2024010...
# 3  dataset\casual_women_summer\Screenshot_2024010...
# 4  dataset\casual_women_summer\Screenshot_2024010...

# %%
final_df1.head()
# Out:
#                  Date    Type Gender weather  \
# 0 2016-06-11 04:22:22  Casual  Women  Summer
# 1 2000-09-13 01:58:44  Formal    Men  Summer
# 2 2012-12-31 18:05:54   Beach    Men  Winter
# 3 2000-12-26 17:21:26  Formal    Men  Summer
# 4 2005-04-22 18:07:04  Formal    Men  Summer
#
#                                                 Path
# 0  dataset\casual_women_summer\Screenshot_2024010...
# 1  dataset\formal_men_summer\80+ Cool Outfits For...
# 2  dataset\beach_men\Pool Party Or Beach Party Ou...
# 3  dataset\formal_men_summer\5 Cool Outfits With ...
# 4  dataset\formal_men_summer\WhatsApp Image 2024-...

# %%
final_df1.shape
# Out:
# (819, 5)

# %%
final_df1.to_csv('dataset.csv',index=False)
