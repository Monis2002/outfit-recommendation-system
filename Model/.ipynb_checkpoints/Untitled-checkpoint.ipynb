# %%
import pandas as pd
import os

# %% [markdown]
# # Random date and time

# %%
import random
from datetime import datetime, timedelta

def generate_random_datetime():
    # Define the start and end dates
    start_date = datetime(2000, 1, 1)
    end_date = datetime(2020, 12, 31)

    # Generate a random number of days between start and end
    random_days = random.randint(0, (end_date - start_date).days)

    # Calculate the random date
    random_date = start_date + timedelta(days=random_days)

    # Generate random hours, minutes, and seconds
    random_hours = random.randint(0, 23)
    random_minutes = random.randint(0, 59)
    random_seconds = random.randint(0, 59)

    # Combine date and time components
    random_datetime = random_date.replace(
        hour=random_hours, minute=random_minutes, second=random_seconds
    )

    return random_datetime

# Example usage
random_datetime = generate_random_datetime()
print("Random Date and Time:", random_datetime)
# Out:
# Random Date and Time: 2010-07-06 02:50:17

# %%
os.listdir('dataset\\formal_male_winter')[:10]
# Out:
# ['#life style.jpeg',
#  '0f9c9f7c5f669b5d9b45dc8cd26d6c2f.jpg',
#  '122e34cbfc9db204583acf3886802127.jpg',
#  '15eb1aaab07383d016ecfc5077dd5735.jpg',
#  "20 Pent Shirt Design & Combination__Formal Dressing Style For Men's.jpeg",
#  '2024 Men’s Formalwear_ Stylish and Business Casual 18 ideas #6.jpeg',
#  '21_Dashing_Formal_Outfit_Ideas_For_Men_1_1200x1200.webp',
#  '2c78a50f-10b5-407c-bfdd-ba3af1b5dedd.jpeg',
#  '33 Ways to Wear & Style White Button Down Shirts For Men.jpeg',
#  '35 Stunning Outfits With Brown Dress Shoes.jpeg']

# %%
dic_list=[]
path_list=os.listdir('dataset\\formal_male_winter')
weather=input('Weather  ')
Type=input("Type  ")

for path in path_list:
    r=os.path.join('dataset\\formal_male_winter',path)
    d={'Date':generate_random_datetime(),'Type':Type,'Gender':"M",'weather':weather,'Path':r}
    dic_list.append(d)
# Out:
# Weather  Summar
# Type  Formal

# %%
df=pd.DataFrame(dic_list)
df.head()
# Out:
#                  Date    Type Gender weather  \
# 0 2010-12-23 11:52:55  Formal      M  Summar
# 1 2017-06-30 07:48:45  Formal      M  Summar
# 2 2001-10-19 12:21:06  Formal      M  Summar
# 3 2003-04-03 07:32:26  Formal      M  Summar
# 4 2011-01-31 18:51:48  Formal      M  Summar
#
#                                                 Path
# 0        dataset\formal_male_winter\#life style.jpeg
# 1  dataset\formal_male_winter\0f9c9f7c5f669b5d9b4...
# 2  dataset\formal_male_winter\122e34cbfc9db204583...
# 3  dataset\formal_male_winter\15eb1aaab07383d016e...
# 4  dataset\formal_male_winter\20 Pent Shirt Desig...

# %%
df.shape
# Out:
# (116, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     116 non-null    datetime64[ns]
#  1   Type     116 non-null    object
#  2   Gender   116 non-null    object
#  3   weather  116 non-null    object
#  4   Path     116 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 4.7+ KB

# %%
df.Date.dt.year
# Out:
# 0      2010
# 1      2017
# 2      2001
# 3      2003
# 4      2011
#        ...
# 111    2005
# 112    2005
# 113    2016
# 114    2019
# 115    2010
# Name: Date, Length: 116, dtype: int32

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img=df.loc[52,'Path']
img
# Out:
# 'dataset\\formal_male_winter\\Dress Well Bro.jpeg'

# %%
img_ar=cv2.imread(img)
img_ar
# Out:
# array([[[117, 145, 156],
#         [122, 150, 161],
#         [135, 161, 173],
#         ...,
#         [157, 174, 187],
#         [158, 175, 188],
#         [158, 175, 188]],
#
#        [[120, 148, 159],
#         [121, 149, 160],
#         [130, 156, 168],
#         ...,
#         [157, 174, 187],
#         [157, 174, 187],
#         [158, 175, 188]],
#
#        [[120, 148, 159],
#         [120, 148, 159],
#         [128, 154, 166],
#         ...,
#         [156, 173, 186],
#         [157, 174, 187],
#         [157, 174, 187]],
#
#        ...,
#
#        [[ 98, 105, 108],
#         [132, 139, 142],
#         [132, 139, 142],
#         ...,
#         [ 98,  86,  82],
#         [ 95,  83,  79],
#         [ 91,  79,  75]],
#
#        [[121, 128, 131],
#         [ 92,  99, 102],
#         [ 91,  98, 101],
#         ...,
#         [ 80,  68,  64],
#         [ 78,  66,  62],
#         [ 78,  66,  62]],
#
#        [[100, 107, 110],
#         [ 97, 104, 107],
#         [ 93, 100, 103],
#         ...,
#         [ 79,  67,  63],
#         [ 78,  66,  62],
#         [ 81,  69,  65]]], dtype=uint8)

# %%
plt.imshow(img_ar)

# %%
df.to_csv('male_formal_winter.csv',index=False)
